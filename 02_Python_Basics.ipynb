# %% [markdown]
# <a href="https://colab.research.google.com/github/hby1117/class2026Fall/blob/main/02_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Basics

# %% [markdown]
# ## 1. Fundamentals
# ```
# y = f(x)
# ```
# 1. Data
# 2. Function
# 3. Flow

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Variable
# ```python
# a = "Hello!"
# ```

# %%
# 예시: 택배 배송 상태 확인하기
product = "무선 이어폰"
delivery_status = "상품 준비 중"

# 1. 상품 준비 중
# 2. 배송 중
# 3. 배송 완료

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Data Type

# %% [markdown]
# ### Numbers
# ```python
# a = 1
# b = 3.14
# ```
# ```python
# # Calculate
# 2 + 3
# 2 - 3
# 2 * 3
# 2 / 3
# 2 // 3
# 2 % 3
# 2 ** 3
# ```

# %%
# 예시: 배달 음식 비용 계산하기
pizza_price = 26000
num_pizza = 2

drink_price = 2000
num_drink = 3

delivery_fee = 3000
coupon = 4000
person_count = 3

# 1. 전체 주문 금액을 계산한다.
# 2. 쿠폰 적용 후 결제 금액을 계산한다.
# 3. 한 명당 금액을 계산한다.

# %% [markdown]
# ### Sequence: String
# ```python
# a = "Hello"
# b = "World!"
# ```
# ```python
# # Access
# a[0]
# a[1:3]
# ```
# ```python
# # Concatenate
# a + b
# ```

# %%
# 예시: 택배 라벨 개인정보 마스킹
name = "성이름"
phone_number = "010-1234-5678"

# 1. 이름을 마스킹한다.
# 2. 전화번호를 마스킹한다.

# %% [markdown]
# ### Sequence: List
# ```python
# a = [1, 3, 5, 7, 9]
# ```
# ```python
# # Access
# a[0]
# a[1:3]
# ```
# ```python
# # Modify
# a[0] = 11
#
# # Append
# a.append(6)
#
# # Remove
# a.pop(2)
# ```

# %%
# 예시: 플레이리스트 만들기

# 1. 곡 3개가 들어 있는 플레이리스트를 만든다.
# 2. 첫 번째 곡을 확인한다.
# 3. 두 번째 곡을 교체한다.
# 4. 원하는 곡을 추가한다.
# 5. 한 곡을 삭제한다.

# %% [markdown]
# ### Dictionary
# ```python
# a = {"name": "John", "age": 20}
# ```
# ```python
# # Access
# a["name"]
#
# # Modify
# a["name"] = "Mark"
#
# # Add
# a["city"] = "Seoul"
#
# # Remove
# del a["city"]

# %%
# 예시: 중고거래 게시글 수정하기

# 1. 중고거래 게시글을 쓴다. (상품, 가격, 상태, 특이사항)
# 2. 중고거래 게시글을 확인한다.
# 3. 가격을 바꾼다.
# 4. 장소를 추가한다.
# 5. 특이사항을 삭제한다.
